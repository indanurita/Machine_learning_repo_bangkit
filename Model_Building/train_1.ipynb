# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 28.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from faiss-cpu) (1.25.2)
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.8.0

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
import faiss
import joblib
import numpy as np

# %%
path = 'drive/MyDrive/capstone/raw_data/jobs3.csv'
df = pd.read_csv(path)
path2 = 'drive/MyDrive/capstone/raw_data/jobs2.csv'
df2 = pd.read_csv(path2)
df
# Out:
#                                                 job_link  \
# 0      https://www.linkedin.com/jobs/view/events-mana...
# 1      https://www.linkedin.com/jobs/view/general-sup...
# 2      https://www.linkedin.com/jobs/view/grill-cook-...
# 3      https://www.linkedin.com/jobs/view/billing-tea...
# 4      https://www.linkedin.com/jobs/view/rn-ccu-at-c...
# ...                                                  ...
# 99995  https://www.linkedin.com/jobs/view/solar-sales...
# 99996  https://ca.linkedin.com/jobs/view/sp%C3%A9cial...
# 99997  https://uk.linkedin.com/jobs/view/b2b-customer...
# 99998  https://www.linkedin.com/jobs/view/operations-...
# 99999  https://www.linkedin.com/jobs/view/senior-test...
#
#                  last_processed_time got_summary got_ner is_being_worked  \
# 0      2024-01-20 10:12:25.028788+00           t       t               f
# 1      2024-01-19 09:45:09.215838+00           t       t               f
# 2      2024-01-19 09:45:09.215838+00           t       t               f
# 3      2024-01-21 06:22:55.474052+00           t       t               f
# 4      2024-01-21 03:34:01.590108+00           t       t               f
# ...                              ...         ...     ...             ...
# 99995  2024-01-19 13:01:07.618251+00           t       t               f
# 99996  2024-01-20 02:42:18.802659+00           t       t               f
# 99997  2024-01-19 09:45:09.215838+00           t       t               f
# 99998  2024-01-20 00:44:02.716032+00           t       t               f
# 99999  2024-01-19 09:45:09.215838+00           t       t               f
#
#                                                job_title  \
# 0                                         Events Manager
# 1      General Superintendent - Lead Field Ops at a G...
# 2                                             Grill Cook
# 3                                      Billing Team Lead
# 4                   RN - CCU at Community Health Systems
# ...                                                  ...
# 99995                             Solar Sales Consultant
# 99996  Spécialiste en procédés administratifs - Respo...
# 99997  B2B Customer Service / Account Support. Global...
# 99998                       OPERATIONS ASSISTANT MANAGER
# 99999                               Senior Test Engineer
#
#                                                  company  \
# 0                                     State of Wisconsin
# 1                                           Michael Page
# 2                             Bob Evans Restaurants, LLC
# 3                                            Leddy Group
# 4                                        Health eCareers
# ...                                                  ...
# 99995                                   V3 Electric, Inc
# 99996  Centre universitaire de santé McGill | McGill ...
# 99997                             Recruitment Revolution
# 99998                                 Dollar Tree Stores
# 99999                                    MKS Instruments
#
#                             job_location  first_seen          search_city  \
# 0                            Madison, WI  2024-01-14           New Glarus
# 1                          Milwaukee, WI  2024-01-13            Milwaukee
# 2                          Princeton, IN  2024-01-13              Indiana
# 3                         Manchester, NH  2024-01-14                Derry
# 4                        Hattiesburg, MS  2024-01-14             Magnolia
# ...                                  ...         ...                  ...
# 99995                      Fairfield, CA  2024-01-14              Antioch
# 99996           Montreal, Quebec, Canada  2024-01-16  Cap-de-la-Madeleine
# 99997  Caerphilly, Wales, United Kingdom  2024-01-13              Cardiff
# 99998                         Marion, IA  2024-01-14       Amana Colonies
# 99999                         Irvine, CA  2024-01-13  San Juan Capistrano
#
#        search_country                search_position   job_level job_type  \
# 0       United States                         Vendor  Mid senior   Onsite
# 1       United States               Field Contractor  Mid senior   Onsite
# 2       United States                Cook Apprentice   Associate   Onsite
# 3       United States                     Supervisor   Associate   Onsite
# 4       United States   Nurse Staff Community Health  Mid senior   Onsite
# ...               ...                            ...         ...      ...
# 99995   United States          Sales Agent Insurance  Mid senior   Onsite
# 99996          Canada        Intelligence Specialist  Mid senior   Onsite
# 99997  United Kingdom  Customer Services Coordinator  Mid senior   Onsite
# 99998   United States                 Set-Key Driver  Mid senior   Onsite
# 99999   United States      Electronics-Test Engineer  Mid senior   Onsite
#
#                                               job_skills
# 0      Event Management, Hospitality Management, Publ...
# 1      Construction Management, Construction Superint...
# 2      Restaurant experience, Knowledge of cooking pr...
# 3      Medical billing, Collections, Account Receivab...
# 4      Nursing, Healthcare, Patient Care, EMR, Commun...
# ...                                                  ...
# 99995  Sales, Customer service, Communication, Presen...
# 99996  Data protection, Data management, HIPAA, Data ...
# 99997  Customer Service, Account Management, Sales, C...
# 99998  Retail, Management, Communication, Interperson...
# 99999  Automation, Software Solutions, Test Procedure...
#
# [100000 rows x 15 columns]

# %%
# Menginisialisasi TfidfVectorizer dan TruncatedSVD
tfidf = TfidfVectorizer(stop_words='english')
svd = TruncatedSVD(n_components=2000)  # Misalnya, kita memilih 100 komponen, max_df=0.8, min_df=2, ngram_range=(1, 2)

# Fungsi untuk memproses data dalam batch
def process_batch(data_batch):
    tfidf_matrix = tfidf.fit_transform(data_batch['job_skills'])  # Sparse matrix
    tfidf_reduced = svd.fit_transform(tfidf_matrix)
    return tfidf_reduced

# Membaca data dalam batch dan mengisi FAISS index
def build_faiss_index(file_path, batch_size=10000):
    index = None
    chunk_iter = pd.read_csv(file_path, chunksize=batch_size)

    for i, data_batch in enumerate(chunk_iter):
        print(f"Processing batch {i + 1}")
        data_batch['job_skills'] = data_batch['job_skills'].fillna('')

        # Proses batch
        tfidf_reduced = process_batch(data_batch)

        if index is None:
            d = tfidf_reduced.shape[1]
            index = faiss.IndexFlatL2(d)  # Membuat indeks FAISS jika belum ada

        index.add(tfidf_reduced)

    return index

# Memuat dan memproses data
file_path = path
faiss_index = build_faiss_index(path)

# Menyimpan model
joblib.dump(tfidf, 'tfidf_model.pkl')
joblib.dump(svd, 'svd_model.pkl')
faiss.write_index(faiss_index, 'faiss_index.idx')
# Out:
# Processing batch 1
# Processing batch 2
# Processing batch 3
# Processing batch 4
# Processing batch 5
# Processing batch 6
# Processing batch 7
# Processing batch 8
# Processing batch 9
# Processing batch 10

# %%
var_explained = svd.explained_variance_ratio_.sum()
print(var_explained)
# Out:
# 0.8165644714173347

# %%
# Memuat model yang telah disimpan
tfidf = joblib.load('tfidf_model.pkl')
svd = joblib.load('svd_model.pkl')
faiss_index = faiss.read_index('faiss_index.idx')

# Fungsi untuk mendapatkan rekomendasi
def get_recommendations(index, tfidf, svd, skills_input, n_recommendations=10):
    skills_tfidf = tfidf.transform([skills_input])
    skills_reduced = svd.transform(skills_tfidf)

    distances, indices = index.search(skills_reduced, n_recommendations)

    # Memuat kembali data untuk mendapatkan nama pekerjaan

    return df['job_title'].iloc[indices[0]]

# %%
input_skills = "physics"
recommended_jobs = get_recommendations(faiss_index, tfidf, svd, input_skills)
print(recommended_jobs)
# Out:
# 90198                           Oncology Physicist
# 93136    Tenure-Track Assistant Professor, Physics
# 96195             Oncology Physicist - hybrid role
# 89870              Medical Technologist Generalist
# 97799                            Senior VFX Artist
# 74087                      Production Area Manager
# 48096          Retrofit Coordinator in Bristol, UK
# 24625      Head Coach Junior High Girls Volleyball
# 94027          Senior Product Development Engineer
# 93083      Principal Process Engineer - Wet Cleans
# Name: job_title, dtype: object

# %%
# Fungsi untuk menghitung Average Precision
def average_precision_at_k(actual, predicted, k):
    if len(predicted) > k:
        predicted = predicted[:k]

    score = 0.0
    num_hits = 0.0

    for i, p in enumerate(predicted):
        if p in actual and p not in predicted[:i]:
            num_hits += 1.0
            score += num_hits / (i + 1.0)

    if not actual:
        return 0.0

    return score / min(len(actual), k)

# Fungsi untuk menghitung MAP
def mean_average_precision(test_data, n_recommendations=10):
    scores = []

    for _, row in test_data.iterrows():
        input_skills = row["job_skills"]
        actual_jobs = [row["job_title"]]

        recommended_jobs = get_recommendations(faiss_index, tfidf, svd, input_skills, n_recommendations)
        score = average_precision_at_k(actual_jobs, recommended_jobs, n_recommendations)
        scores.append(score)

    return np.mean(scores)

# %%
test_data = df.sample(n= 100, random_state= 2)

# %%
map_score = mean_average_precision(test_data, n_recommendations=10)
print(f"Mean Average Precision: {map_score:.2f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b9126f342ddf> in <cell line: 1>()
# ----> 1 map_score = mean_average_precision(test_data, n_recommendations=10)
#       2 print(f"Mean Average Precision: {map_score:.2f}")
#
# NameError: name 'mean_average_precision' is not defined
