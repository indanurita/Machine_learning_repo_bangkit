# %%
'''melakukan import library yang digunakanan'''
import numpy as numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# membuka file yang digunakan
job_posting_df = pd.read_csv('/kaggle/input/1-3m-linkedin-jobs-and-skills-2024/linkedin_job_postings.csv')
job_posting_df.head()
# Out:
#                                             job_link  \
# 0  https://www.linkedin.com/jobs/view/account-exe...
# 1  https://www.linkedin.com/jobs/view/registered-...
# 2  https://www.linkedin.com/jobs/view/restaurant-...
# 3  https://www.linkedin.com/jobs/view/independent...
# 4  https://www.linkedin.com/jobs/view/group-unit-...
#
#              last_processed_time got_summary got_ner is_being_worked  \
# 0   2024-01-21 07:12:29.00256+00           t       t               f
# 1   2024-01-21 07:39:58.88137+00           t       t               f
# 2  2024-01-21 07:40:00.251126+00           t       t               f
# 3  2024-01-21 07:40:00.308133+00           t       t               f
# 4  2024-01-19 09:45:09.215838+00           f       f               f
#
#                                            job_title  \
# 0  Account Executive - Dispensing (NorCal/Norther...
# 1                 Registered Nurse - RN Care Manager
# 2               RESTAURANT SUPERVISOR - THE FORKLIFT
# ...

# %%
#menilai data, melihat info, serta memeriksa missing value
job_posting_df.info()
job_posting_df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1348454 entries, 0 to 1348453
# Data columns (total 14 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   job_link             1348454 non-null  object
#  1   last_processed_time  1348454 non-null  object
#  2   got_summary          1348454 non-null  object
#  3   got_ner              1348454 non-null  object
#  4   is_being_worked      1348454 non-null  object
#  5   job_title            1348454 non-null  object
#  6   company              1348443 non-null  object
#  7   job_location         1348435 non-null  object
#  8   first_seen           1348454 non-null  object
#  9   search_city          1348454 non-null  object
#  10  search_country       1348454 non-null  object
#  11  search_position      1348454 non-null  object
#  12  job_level            1348454 non-null  object
#  13  job_type             1348454 non-null  object
# dtypes: object(14)
# ...

# %%
#memeriksa jumlah duplikasi data
print("Jumlah duplikasi: ", job_posting_df.duplicated().sum())
#memeriksa parameter statistik 
job_posting_df.describe()
# Out:
# Jumlah duplikasi:  0
#                                                  job_link  \
# count                                             1348454
# unique                                            1348454
# top     https://www.linkedin.com/jobs/view/account-exe...
# freq                                                    1
#
#                   last_processed_time got_summary  got_ner is_being_worked  \
# count                         1348454     1348454  1348454         1348454
# unique                         722748           2        2               2
# top     2024-01-19 09:45:09.215838+00           t        t               f
# freq                           625540     1297877  1296401         1346978
#
#                       job_title          company  job_location  first_seen  \
# count                   1348454          1348443       1348435     1348454
# unique                   584544            90605         29153           6
# ...

# %%
#menampilkan data yang mengalami missing value
job_posting_df[job_posting_df.company.isna()]
job_posting_df[job_posting_df.job_location.isna()]
# Out:
#                                                   job_link  \
# 118051   https://fr.linkedin.com/jobs/view/superviseur-...
# 121181   https://www.linkedin.com/jobs/view/med-surg-rn...
# 138655   https://www.linkedin.com/jobs/view/family-law-...
# 222819   https://www.linkedin.com/jobs/view/civil-proje...
# 327983   https://au.linkedin.com/jobs/view/senior-contr...
# 374834   https://www.linkedin.com/jobs/view/controls-en...
# 398059   https://ca.linkedin.com/jobs/view/player-devel...
# 426624   https://www.linkedin.com/jobs/view/research-sc...
# 460534   https://www.linkedin.com/jobs/view/hris-analys...
# 484639   https://www.linkedin.com/jobs/view/rn-residenc...
# 538647   https://www.linkedin.com/jobs/view/senior-cons...
# 633565   https://www.linkedin.com/jobs/view/controls-en...
# 634103   https://uk.linkedin.com/jobs/view/electrical-d...
# 634484   https://www.linkedin.com/jobs/view/lead-engine...
# 634639   https://uk.linkedin.com/jobs/view/senior-elect...
# ...

# %%
#menghilangkan missing value
job_posting_dfC = job_posting_df.dropna(axis = 0, inplace = False)

# %%
job_posting_dfC.isna().sum()
# Out:
# job_link               0
# last_processed_time    0
# got_summary            0
# got_ner                0
# is_being_worked        0
# job_title              0
# company                0
# job_location           0
# first_seen             0
# search_city            0
# search_country         0
# search_position        0
# job_level              0
# job_type               0
# dtype: int64
